# %% [markdown]
# <a href="https://colab.research.google.com/github/cahyaekapermana/chocolatefruitripeness_cnn/blob/main/proyek3_chocolatefruitripeness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PS: Create your kaggle credentials then upload to your runtime before running the script since the data source is public kaggle datasets**

# %% [markdown]
# Koneksi ke kaggle dikarenakan dataset yang digunakan melalui kagle

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Download dan unzip dataset coklat dari kagle

# %%
! kaggle datasets download juanfelipeheredia/cocoa-ripeness-dataset-tcs-01
# Out:
# Downloading cocoa-ripeness-dataset-tcs-01.zip to /content
#  75% 33.0M/44.1M [00:00<00:00, 64.3MB/s]
# 100% 44.1M/44.1M [00:00<00:00, 69.4MB/s]

# %%
# !unzip cocoa-ripeness-dataset-tcs-01.zip
# Out:
# Archive:  cocoa-ripeness-dataset-tcs-01.zip
#   inflating: Cocoa Ripeness Dataset/I1.jpg
#   inflating: Cocoa Ripeness Dataset/I10.jpg
#   inflating: Cocoa Ripeness Dataset/I100.jpg
#   inflating: Cocoa Ripeness Dataset/I101.jpg
#   inflating: Cocoa Ripeness Dataset/I102.jpg
#   inflating: Cocoa Ripeness Dataset/I103.jpg
#   inflating: Cocoa Ripeness Dataset/I104.jpg
#   inflating: Cocoa Ripeness Dataset/I105.jpg
#   inflating: Cocoa Ripeness Dataset/I106.jpg
#   inflating: Cocoa Ripeness Dataset/I107.jpg
#   inflating: Cocoa Ripeness Dataset/I108.jpg
#   inflating: Cocoa Ripeness Dataset/I109.jpg
#   inflating: Cocoa Ripeness Dataset/I11.jpg
#   inflating: Cocoa Ripeness Dataset/I110.jpg
#   inflating: Cocoa Ripeness Dataset/I111.jpg
#   inflating: Cocoa Ripeness Dataset/I112.jpg
#   inflating: Cocoa Ripeness Dataset/I113.jpg
#   inflating: Cocoa Ripeness Dataset/I114.jpg
#   inflating: Cocoa Ripeness Dataset/I115.jpg
#   inflating: Cocoa Ripeness Dataset/I116.jpg
#   inflating: Cocoa Ripeness Dataset/I117.jpg
#   inflating: Cocoa Ripeness Dataset/I118.jpg
#   inflating: Cocoa Ripeness Dataset/I119.jpg
#   inflating: Cocoa Ripeness Dataset/I12.jpg
#   inflating: Cocoa Ripeness Dataset/I120.jpg
#   inflating: Cocoa Ripeness Dataset/I121.jpg
#   inflating: Cocoa Ripeness Dataset/I122.jpg
#   inflating: Cocoa Ripeness Dataset/I123.jpg
#   inflating: Cocoa Ripeness Dataset/I124.jpg
#   inflating: Cocoa Ripeness Dataset/I125.jpg
#   inflating: Cocoa Ripeness Dataset/I126.jpg
#   inflating: Cocoa Ripeness Dataset/I127.jpg
#   inflating: Cocoa Ripeness Dataset/I128.jpg
#   inflating: Cocoa Ripeness Dataset/I129.jpg
#   inflating: Cocoa Ripeness Dataset/I13.jpg
#   inflating: Cocoa Ripeness Dataset/I130.jpg
#   inflating: Cocoa Ripeness Dataset/I131.jpg
#   inflating: Cocoa Ripeness Dataset/I132.jpg
#   inflating: Cocoa Ripeness Dataset/I133.jpg
#   inflating: Cocoa Ripeness Dataset/I134.jpg
#   inflating: Cocoa Ripeness Dataset/I135.jpg
#   inflating: Cocoa Ripeness Dataset/I136.jpg
#   inflating: Cocoa Ripeness Dataset/I137.jpg
#   inflating: Cocoa Ripeness Dataset/I138.jpg
#   inflating: Cocoa Ripeness Dataset/I139.jpg
#   inflating: Cocoa Ripeness Dataset/I14.jpg
#   inflating: Cocoa Ripeness Dataset/I140.jpg
#   inflating: Cocoa Ripeness Dataset/I141.jpg
#   inflating: Cocoa Ripeness Dataset/I142.jpg
#   inflating: Cocoa Ripeness Dataset/I143.jpg
#   inflating: Cocoa Ripeness Dataset/I144.jpg
#   inflating: Cocoa Ripeness Dataset/I145.jpg
#   inflating: Cocoa Ripeness Dataset/I146.jpg
#   inflating: Cocoa Ripeness Dataset/I147.jpg
#   inflating: Cocoa Ripeness Dataset/I148.jpg
#   inflating: Cocoa Ripeness Dataset/I149.jpg
#   inflating: Cocoa Ripeness Dataset/I15.jpg
#   inflating: Cocoa Ripeness Dataset/I150.jpg
#   inflating: Cocoa Ripeness Dataset/I151.jpg
#   inflating: Cocoa Ripeness Dataset/I152.jpg
#   inflating: Cocoa Ripeness Dataset/I153.jpg
#   inflating: Cocoa Ripeness Dataset/I154.jpg
#   inflating: Cocoa Ripeness Dataset/I155.jpg
#   inflating: Cocoa Ripeness Dataset/I156.jpg
#   inflating: Cocoa Ripeness Dataset/I157.jpg
#   inflating: Cocoa Ripeness Dataset/I158.jpg
#   inflating: Cocoa Ripeness Dataset/I159.jpg
#   inflating: Cocoa Ripeness Dataset/I16.jpg
#   inflating: Cocoa Ripeness Dataset/I160.jpg
#   inflating: Cocoa Ripeness Dataset/I161.jpg
#   inflating: Cocoa Ripeness Dataset/I162.jpg
#   inflating: Cocoa Ripeness Dataset/I163.jpg
#   inflating: Cocoa Ripeness Dataset/I164.jpg
#   inflating: Cocoa Ripeness Dataset/I165.jpg
#   inflating: Cocoa Ripeness Dataset/I166.jpg
#   inflating: Cocoa Ripeness Dataset/I167.jpg
#   inflating: Cocoa Ripeness Dataset/I168.jpg
#   inflating: Cocoa Ripeness Dataset/I169.jpg
#   inflating: Cocoa Ripeness Dataset/I17.jpg
#   inflating: Cocoa Ripeness Dataset/I170.jpg
#   inflating: Cocoa Ripeness Dataset/I171.jpg
#   inflating: Cocoa Ripeness Dataset/I172.jpg
#   inflating: Cocoa Ripeness Dataset/I173.jpg
#   inflating: Cocoa Ripeness Dataset/I174.jpg
#   inflating: Cocoa Ripeness Dataset/I175.jpg
#   inflating: Cocoa Ripeness Dataset/I176.jpg
#   inflating: Cocoa Ripeness Dataset/I177.jpg
#   inflating: Cocoa Ripeness Dataset/I178.jpg
#   inflating: Cocoa Ripeness Dataset/I179.jpg
#   inflating: Cocoa Ripeness Dataset/I18.jpg
#   inflating: Cocoa Ripeness Dataset/I180.jpg
#   inflating: Cocoa Ripeness Dataset/I181.jpg
#   inflating: Cocoa Ripeness Dataset/I182.jpg
#   inflating: Cocoa Ripeness Dataset/I183.jpg
#   inflating: Cocoa Ripeness Dataset/I184.jpg
#   inflating: Cocoa Ripeness Dataset/I185.jpg
#   inflating: Cocoa Ripeness Dataset/I186.jpg
#   inflating: Cocoa Ripeness Dataset/I187.jpg
#   inflating: Cocoa Ripeness Dataset/I188.jpg
#   inflating: Cocoa Ripeness Dataset/I189.jpg
#   inflating: Cocoa Ripeness Dataset/I19.jpg
#   inflating: Cocoa Ripeness Dataset/I190.jpg
#   inflating: Cocoa Ripeness Dataset/I191.jpg
#   inflating: Cocoa Ripeness Dataset/I192.jpg
#   inflating: Cocoa Ripeness Dataset/I193.jpg
#   inflating: Cocoa Ripeness Dataset/I194.jpg
#   inflating: Cocoa Ripeness Dataset/I195.jpg
#   inflating: Cocoa Ripeness Dataset/I196.jpg
#   inflating: Cocoa Ripeness Dataset/I197.jpg
#   inflating: Cocoa Ripeness Dataset/I198.jpg
#   inflating: Cocoa Ripeness Dataset/I199.jpg
#   inflating: Cocoa Ripeness Dataset/I2.jpg
#   inflating: Cocoa Ripeness Dataset/I20.jpg
#   inflating: Cocoa Ripeness Dataset/I200.jpg
#   inflating: Cocoa Ripeness Dataset/I201.jpg
#   inflating: Cocoa Ripeness Dataset/I202.jpg
#   inflating: Cocoa Ripeness Dataset/I203.jpg
#   inflating: Cocoa Ripeness Dataset/I204.jpg
#   inflating: Cocoa Ripeness Dataset/I205.jpg
#   inflating: Cocoa Ripeness Dataset/I206.jpg
#   inflating: Cocoa Ripeness Dataset/I207.jpg
#   inflating: Cocoa Ripeness Dataset/I208.jpg
#   inflating: Cocoa Ripeness Dataset/I209.jpg
#   inflating: Cocoa Ripeness Dataset/I21.jpg
#   inflating: Cocoa Ripeness Dataset/I210.jpg
#   inflating: Cocoa Ripeness Dataset/I211.jpg
#   inflating: Cocoa Ripeness Dataset/I212.jpg
#   inflating: Cocoa Ripeness Dataset/I213.jpg
#   inflating: Cocoa Ripeness Dataset/I214.jpg
#   inflating: Cocoa Ripeness Dataset/I215.jpg
#   inflating: Cocoa Ripeness Dataset/I216.jpg
#   inflating: Cocoa Ripeness Dataset/I217.jpg
#   inflating: Cocoa Ripeness Dataset/I218.jpg
#   inflating: Cocoa Ripeness Dataset/I219.jpg
#   inflating: Cocoa Ripeness Dataset/I22.jpg
#   inflating: Cocoa Ripeness Dataset/I220.jpg
#   inflating: Cocoa Ripeness Dataset/I221.jpg
#   inflating: Cocoa Ripeness Dataset/I222.jpg
#   inflating: Cocoa Ripeness Dataset/I223.jpg
#   inflating: Cocoa Ripeness Dataset/I224.jpg
#   inflating: Cocoa Ripeness Dataset/I225.jpg
#   inflating: Cocoa Ripeness Dataset/I226.jpg
#   inflating: Cocoa Ripeness Dataset/I227.jpg
#   inflating: Cocoa Ripeness Dataset/I228.jpg
#   inflating: Cocoa Ripeness Dataset/I229.jpg
#   inflating: Cocoa Ripeness Dataset/I23.jpg
#   inflating: Cocoa Ripeness Dataset/I230.jpg
#   inflating: Cocoa Ripeness Dataset/I231.jpg
#   inflating: Cocoa Ripeness Dataset/I232.jpg
#   inflating: Cocoa Ripeness Dataset/I233.jpg
#   inflating: Cocoa Ripeness Dataset/I234.jpg
#   inflating: Cocoa Ripeness Dataset/I235.jpg
#   inflating: Cocoa Ripeness Dataset/I236.jpg
#   inflating: Cocoa Ripeness Dataset/I237.jpg
#   inflating: Cocoa Ripeness Dataset/I238.jpg
#   inflating: Cocoa Ripeness Dataset/I239.jpg
#   inflating: Cocoa Ripeness Dataset/I24.jpg
#   inflating: Cocoa Ripeness Dataset/I240.jpg
#   inflating: Cocoa Ripeness Dataset/I241.jpg
#   inflating: Cocoa Ripeness Dataset/I242.jpg
#   inflating: Cocoa Ripeness Dataset/I243.jpg
#   inflating: Cocoa Ripeness Dataset/I244.jpg
#   inflating: Cocoa Ripeness Dataset/I245.jpg
#   inflating: Cocoa Ripeness Dataset/I246.jpg
#   inflating: Cocoa Ripeness Dataset/I247.jpg
#   inflating: Cocoa Ripeness Dataset/I248.jpg
#   inflating: Cocoa Ripeness Dataset/I249.jpg
#   inflating: Cocoa Ripeness Dataset/I25.jpg
#   inflating: Cocoa Ripeness Dataset/I250.jpg
#   inflating: Cocoa Ripeness Dataset/I251.jpg
#   inflating: Cocoa Ripeness Dataset/I252.jpg
#   inflating: Cocoa Ripeness Dataset/I253.jpg
#   inflating: Cocoa Ripeness Dataset/I254.jpg
#   inflating: Cocoa Ripeness Dataset/I255.jpg
#   inflating: Cocoa Ripeness Dataset/I256.jpg
#   inflating: Cocoa Ripeness Dataset/I257.jpg
#   inflating: Cocoa Ripeness Dataset/I258.jpg
#   inflating: Cocoa Ripeness Dataset/I259.jpg
#   inflating: Cocoa Ripeness Dataset/I26.jpg
#   inflating: Cocoa Ripeness Dataset/I260.jpg
#   inflating: Cocoa Ripeness Dataset/I261.jpg
#   inflating: Cocoa Ripeness Dataset/I262.jpg
#   inflating: Cocoa Ripeness Dataset/I263.jpg
#   inflating: Cocoa Ripeness Dataset/I27.jpg
#   inflating: Cocoa Ripeness Dataset/I28.jpg
#   inflating: Cocoa Ripeness Dataset/I29.jpg
#   inflating: Cocoa Ripeness Dataset/I3.jpg
#   inflating: Cocoa Ripeness Dataset/I30.jpg
#   inflating: Cocoa Ripeness Dataset/I31.jpg
#   inflating: Cocoa Ripeness Dataset/I32.jpg
#   inflating: Cocoa Ripeness Dataset/I33.jpg
#   inflating: Cocoa Ripeness Dataset/I34.jpg
#   inflating: Cocoa Ripeness Dataset/I35.jpg
#   inflating: Cocoa Ripeness Dataset/I36.jpg
#   inflating: Cocoa Ripeness Dataset/I37.jpg
#   inflating: Cocoa Ripeness Dataset/I38.jpg
#   inflating: Cocoa Ripeness Dataset/I39.jpg
#   inflating: Cocoa Ripeness Dataset/I4.jpg
#   inflating: Cocoa Ripeness Dataset/I40.jpg
#   inflating: Cocoa Ripeness Dataset/I41.jpg
#   inflating: Cocoa Ripeness Dataset/I42.jpg
#   inflating: Cocoa Ripeness Dataset/I43.jpg
#   inflating: Cocoa Ripeness Dataset/I44.jpg
#   inflating: Cocoa Ripeness Dataset/I45.jpg
#   inflating: Cocoa Ripeness Dataset/I46.jpg
#   inflating: Cocoa Ripeness Dataset/I47.jpg
#   inflating: Cocoa Ripeness Dataset/I48.jpg
#   inflating: Cocoa Ripeness Dataset/I49.jpg
#   inflating: Cocoa Ripeness Dataset/I5.jpg
#   inflating: Cocoa Ripeness Dataset/I50.jpg
#   inflating: Cocoa Ripeness Dataset/I51.jpg
#   inflating: Cocoa Ripeness Dataset/I52.jpg
#   inflating: Cocoa Ripeness Dataset/I53.jpg
#   inflating: Cocoa Ripeness Dataset/I54.jpg
#   inflating: Cocoa Ripeness Dataset/I55.jpg
#   inflating: Cocoa Ripeness Dataset/I56.jpg
#   inflating: Cocoa Ripeness Dataset/I57.jpg
#   inflating: Cocoa Ripeness Dataset/I58.jpg
#   inflating: Cocoa Ripeness Dataset/I59.jpg
#   inflating: Cocoa Ripeness Dataset/I6.jpg
#   inflating: Cocoa Ripeness Dataset/I60.jpg
#   inflating: Cocoa Ripeness Dataset/I61.jpg
#   inflating: Cocoa Ripeness Dataset/I62.jpg
#   inflating: Cocoa Ripeness Dataset/I63.jpg
#   inflating: Cocoa Ripeness Dataset/I64.jpg
#   inflating: Cocoa Ripeness Dataset/I65.jpg
#   inflating: Cocoa Ripeness Dataset/I66.jpg
#   inflating: Cocoa Ripeness Dataset/I67.jpg
#   inflating: Cocoa Ripeness Dataset/I68.jpg
#   inflating: Cocoa Ripeness Dataset/I69.jpg
#   inflating: Cocoa Ripeness Dataset/I7.jpg
#   inflating: Cocoa Ripeness Dataset/I70.jpg
#   inflating: Cocoa Ripeness Dataset/I71.jpg
#   inflating: Cocoa Ripeness Dataset/I72.jpg
#   inflating: Cocoa Ripeness Dataset/I73.jpg
#   inflating: Cocoa Ripeness Dataset/I74.jpg
#   inflating: Cocoa Ripeness Dataset/I75.jpg
#   inflating: Cocoa Ripeness Dataset/I76.jpg
#   inflating: Cocoa Ripeness Dataset/I77.jpg
#   inflating: Cocoa Ripeness Dataset/I78.jpg
#   inflating: Cocoa Ripeness Dataset/I79.jpg
#   inflating: Cocoa Ripeness Dataset/I8.jpg
#   inflating: Cocoa Ripeness Dataset/I80.jpg
#   inflating: Cocoa Ripeness Dataset/I81.jpg
#   inflating: Cocoa Ripeness Dataset/I82.jpg
#   inflating: Cocoa Ripeness Dataset/I83.jpg
#   inflating: Cocoa Ripeness Dataset/I84.jpg
#   inflating: Cocoa Ripeness Dataset/I85.jpg
#   inflating: Cocoa Ripeness Dataset/I86.jpg
#   inflating: Cocoa Ripeness Dataset/I87.jpg
#   inflating: Cocoa Ripeness Dataset/I88.jpg
#   inflating: Cocoa Ripeness Dataset/I89.jpg
#   inflating: Cocoa Ripeness Dataset/I9.jpg
#   inflating: Cocoa Ripeness Dataset/I90.jpg
#   inflating: Cocoa Ripeness Dataset/I91.jpg
#   inflating: Cocoa Ripeness Dataset/I92.jpg
#   inflating: Cocoa Ripeness Dataset/I93.jpg
#   inflating: Cocoa Ripeness Dataset/I94.jpg
#   inflating: Cocoa Ripeness Dataset/I95.jpg
#   inflating: Cocoa Ripeness Dataset/I96.jpg
#   inflating: Cocoa Ripeness Dataset/I97.jpg
#   inflating: Cocoa Ripeness Dataset/I98.jpg
#   inflating: Cocoa Ripeness Dataset/I99.jpg
#   inflating: Cocoa Ripeness Dataset/M1.jpg
#   inflating: Cocoa Ripeness Dataset/M10.jpg
#   inflating: Cocoa Ripeness Dataset/M11.jpg
#   inflating: Cocoa Ripeness Dataset/M12.jpg
#   inflating: Cocoa Ripeness Dataset/M13.jpg
#   inflating: Cocoa Ripeness Dataset/M14.jpg
#   inflating: Cocoa Ripeness Dataset/M15.jpg
#   inflating: Cocoa Ripeness Dataset/M16.jpg
#   inflating: Cocoa Ripeness Dataset/M17.jpg
#   inflating: Cocoa Ripeness Dataset/M18.jpg
#   inflating: Cocoa Ripeness Dataset/M19.jpg
#   inflating: Cocoa Ripeness Dataset/M2.jpg
#   inflating: Cocoa Ripeness Dataset/M20.jpg
#   inflating: Cocoa Ripeness Dataset/M21.jpg
#   inflating: Cocoa Ripeness Dataset/M22.jpg
#   inflating: Cocoa Ripeness Dataset/M23.jpg
#   inflating: Cocoa Ripeness Dataset/M24.jpg
#   inflating: Cocoa Ripeness Dataset/M25.jpg
#   inflating: Cocoa Ripeness Dataset/M26.jpg
#   inflating: Cocoa Ripeness Dataset/M27.jpg
#   inflating: Cocoa Ripeness Dataset/M28.jpg
#   inflating: Cocoa Ripeness Dataset/M29.jpg
#   inflating: Cocoa Ripeness Dataset/M3.jpg
#   inflating: Cocoa Ripeness Dataset/M30.jpg
#   inflating: Cocoa Ripeness Dataset/M31.jpg
#   inflating: Cocoa Ripeness Dataset/M32.jpg
#   inflating: Cocoa Ripeness Dataset/M33.jpg
#   inflating: Cocoa Ripeness Dataset/M34.jpg
#   inflating: Cocoa Ripeness Dataset/M35.jpg
#   inflating: Cocoa Ripeness Dataset/M36.jpg
#   inflating: Cocoa Ripeness Dataset/M37.jpg
#   inflating: Cocoa Ripeness Dataset/M38.jpg
#   inflating: Cocoa Ripeness Dataset/M39.jpg
#   inflating: Cocoa Ripeness Dataset/M4.jpg
#   inflating: Cocoa Ripeness Dataset/M40.jpg
#   inflating: Cocoa Ripeness Dataset/M41.jpg
#   inflating: Cocoa Ripeness Dataset/M42.jpg
#   inflating: Cocoa Ripeness Dataset/M43.jpg
#   inflating: Cocoa Ripeness Dataset/M44.jpg
#   inflating: Cocoa Ripeness Dataset/M45.jpg
#   inflating: Cocoa Ripeness Dataset/M46.jpg
#   inflating: Cocoa Ripeness Dataset/M47.jpg
#   inflating: Cocoa Ripeness Dataset/M48.jpg
#   inflating: Cocoa Ripeness Dataset/M49.jpg
#   inflating: Cocoa Ripeness Dataset/M5.jpg
#   inflating: Cocoa Ripeness Dataset/M50.jpg
#   inflating: Cocoa Ripeness Dataset/M51.jpg
#   inflating: Cocoa Ripeness Dataset/M52.jpg
#   inflating: Cocoa Ripeness Dataset/M53.jpg
#   inflating: Cocoa Ripeness Dataset/M54.jpg
#   inflating: Cocoa Ripeness Dataset/M55.jpg
#   inflating: Cocoa Ripeness Dataset/M56.jpg
#   inflating: Cocoa Ripeness Dataset/M57.jpg
#   inflating: Cocoa Ripeness Dataset/M58.jpg
#   inflating: Cocoa Ripeness Dataset/M59.jpg
#   inflating: Cocoa Ripeness Dataset/M6.jpg
#   inflating: Cocoa Ripeness Dataset/M60.jpg
#   inflating: Cocoa Ripeness Dataset/M61.jpg
#   inflating: Cocoa Ripeness Dataset/M62.jpg
#   inflating: Cocoa Ripeness Dataset/M63.jpg
#   inflating: Cocoa Ripeness Dataset/M64.jpg
#   inflating: Cocoa Ripeness Dataset/M65.jpg
#   inflating: Cocoa Ripeness Dataset/M66.jpg
#   inflating: Cocoa Ripeness Dataset/M67.jpg
#   inflating: Cocoa Ripeness Dataset/M68.jpg
#   inflating: Cocoa Ripeness Dataset/M69.jpg
#   inflating: Cocoa Ripeness Dataset/M7.jpg
#   inflating: Cocoa Ripeness Dataset/M70.jpg
#   inflating: Cocoa Ripeness Dataset/M71.jpg
#   inflating: Cocoa Ripeness Dataset/M72.jpg
#   inflating: Cocoa Ripeness Dataset/M73.jpg
#   inflating: Cocoa Ripeness Dataset/M74.jpg
#   inflating: Cocoa Ripeness Dataset/M75.jpg
#   inflating: Cocoa Ripeness Dataset/M76.jpg
#   inflating: Cocoa Ripeness Dataset/M8.jpg
#   inflating: Cocoa Ripeness Dataset/M9.jpg
#   inflating: Cocoa Ripeness Dataset/S1.jpg
#   inflating: Cocoa Ripeness Dataset/S10.jpg
#   inflating: Cocoa Ripeness Dataset/S100.jpg
#   inflating: Cocoa Ripeness Dataset/S101.jpg
#   inflating: Cocoa Ripeness Dataset/S102.jpg
#   inflating: Cocoa Ripeness Dataset/S103.jpg
#   inflating: Cocoa Ripeness Dataset/S104.jpg
#   inflating: Cocoa Ripeness Dataset/S105.jpg
#   inflating: Cocoa Ripeness Dataset/S106.jpg
#   inflating: Cocoa Ripeness Dataset/S107.jpg
#   inflating: Cocoa Ripeness Dataset/S108.jpg
#   inflating: Cocoa Ripeness Dataset/S109.jpg
#   inflating: Cocoa Ripeness Dataset/S11.jpg
#   inflating: Cocoa Ripeness Dataset/S110.jpg
#   inflating: Cocoa Ripeness Dataset/S111.jpg
#   inflating: Cocoa Ripeness Dataset/S112.jpg
#   inflating: Cocoa Ripeness Dataset/S113.jpg
#   inflating: Cocoa Ripeness Dataset/S114.jpg
#   inflating: Cocoa Ripeness Dataset/S115.jpg
#   inflating: Cocoa Ripeness Dataset/S116.jpg
#   inflating: Cocoa Ripeness Dataset/S117.jpg
#   inflating: Cocoa Ripeness Dataset/S118.jpg
#   inflating: Cocoa Ripeness Dataset/S119.jpg
#   inflating: Cocoa Ripeness Dataset/S12.jpg
#   inflating: Cocoa Ripeness Dataset/S120.jpg
#   inflating: Cocoa Ripeness Dataset/S121.jpg
#   inflating: Cocoa Ripeness Dataset/S122.jpg
#   inflating: Cocoa Ripeness Dataset/S123.jpg
#   inflating: Cocoa Ripeness Dataset/S124.jpg
#   inflating: Cocoa Ripeness Dataset/S125.jpg
#   inflating: Cocoa Ripeness Dataset/S126.jpg
#   inflating: Cocoa Ripeness Dataset/S127.jpg
#   inflating: Cocoa Ripeness Dataset/S128.jpg
#   inflating: Cocoa Ripeness Dataset/S129.jpg
#   inflating: Cocoa Ripeness Dataset/S13.jpg
#   inflating: Cocoa Ripeness Dataset/S130.jpg
#   inflating: Cocoa Ripeness Dataset/S131.jpg
#   inflating: Cocoa Ripeness Dataset/S132.jpg
#   inflating: Cocoa Ripeness Dataset/S133.jpg
#   inflating: Cocoa Ripeness Dataset/S134.jpg
#   inflating: Cocoa Ripeness Dataset/S135.jpg
#   inflating: Cocoa Ripeness Dataset/S136.jpg
#   inflating: Cocoa Ripeness Dataset/S137.jpg
#   inflating: Cocoa Ripeness Dataset/S14.jpg
#   inflating: Cocoa Ripeness Dataset/S15.jpg
#   inflating: Cocoa Ripeness Dataset/S16.jpg
#   inflating: Cocoa Ripeness Dataset/S17.jpg
#   inflating: Cocoa Ripeness Dataset/S18.jpg
#   inflating: Cocoa Ripeness Dataset/S19.jpg
#   inflating: Cocoa Ripeness Dataset/S2.jpg
#   inflating: Cocoa Ripeness Dataset/S20.jpg
#   inflating: Cocoa Ripeness Dataset/S21.jpg
#   inflating: Cocoa Ripeness Dataset/S22.jpg
#   inflating: Cocoa Ripeness Dataset/S23.jpg
#   inflating: Cocoa Ripeness Dataset/S24.jpg
#   inflating: Cocoa Ripeness Dataset/S25.jpg
#   inflating: Cocoa Ripeness Dataset/S26.jpg
#   inflating: Cocoa Ripeness Dataset/S27.jpg
#   inflating: Cocoa Ripeness Dataset/S28.jpg
#   inflating: Cocoa Ripeness Dataset/S29.jpg
#   inflating: Cocoa Ripeness Dataset/S3.jpg
#   inflating: Cocoa Ripeness Dataset/S30.jpg
#   inflating: Cocoa Ripeness Dataset/S31.jpg
#   inflating: Cocoa Ripeness Dataset/S32.jpg
#   inflating: Cocoa Ripeness Dataset/S33.jpg
#   inflating: Cocoa Ripeness Dataset/S34.jpg
#   inflating: Cocoa Ripeness Dataset/S35.jpg
#   inflating: Cocoa Ripeness Dataset/S36.jpg
#   inflating: Cocoa Ripeness Dataset/S37.jpg
#   inflating: Cocoa Ripeness Dataset/S38.jpg
#   inflating: Cocoa Ripeness Dataset/S39.jpg
#   inflating: Cocoa Ripeness Dataset/S4.jpg
#   inflating: Cocoa Ripeness Dataset/S40.jpg
#   inflating: Cocoa Ripeness Dataset/S41.jpg
#   inflating: Cocoa Ripeness Dataset/S42.jpg
#   inflating: Cocoa Ripeness Dataset/S43.jpg
#   inflating: Cocoa Ripeness Dataset/S44.jpg
#   inflating: Cocoa Ripeness Dataset/S45.jpg
#   inflating: Cocoa Ripeness Dataset/S46.jpg
#   inflating: Cocoa Ripeness Dataset/S47.jpg
#   inflating: Cocoa Ripeness Dataset/S48.jpg
#   inflating: Cocoa Ripeness Dataset/S49.jpg
#   inflating: Cocoa Ripeness Dataset/S5.jpg
#   inflating: Cocoa Ripeness Dataset/S50.jpg
#   inflating: Cocoa Ripeness Dataset/S51.jpg
#   inflating: Cocoa Ripeness Dataset/S52.jpg
#   inflating: Cocoa Ripeness Dataset/S53.jpg
#   inflating: Cocoa Ripeness Dataset/S54.jpg
#   inflating: Cocoa Ripeness Dataset/S55.jpg
#   inflating: Cocoa Ripeness Dataset/S56.jpg
#   inflating: Cocoa Ripeness Dataset/S57.jpg
#   inflating: Cocoa Ripeness Dataset/S58.jpg
#   inflating: Cocoa Ripeness Dataset/S59.jpg
#   inflating: Cocoa Ripeness Dataset/S6.jpg
#   inflating: Cocoa Ripeness Dataset/S60.jpg
#   inflating: Cocoa Ripeness Dataset/S61.jpg
#   inflating: Cocoa Ripeness Dataset/S62.jpg
#   inflating: Cocoa Ripeness Dataset/S63.jpg
#   inflating: Cocoa Ripeness Dataset/S64.jpg
#   inflating: Cocoa Ripeness Dataset/S65.jpg
#   inflating: Cocoa Ripeness Dataset/S66.jpg
#   inflating: Cocoa Ripeness Dataset/S67.jpg
#   inflating: Cocoa Ripeness Dataset/S68.jpg
#   inflating: Cocoa Ripeness Dataset/S69.jpg
#   inflating: Cocoa Ripeness Dataset/S7.jpg
#   inflating: Cocoa Ripeness Dataset/S70.jpg
#   inflating: Cocoa Ripeness Dataset/S71.jpg
#   inflating: Cocoa Ripeness Dataset/S72.jpg
#   inflating: Cocoa Ripeness Dataset/S73.jpg
#   inflating: Cocoa Ripeness Dataset/S74.jpg
#   inflating: Cocoa Ripeness Dataset/S75.jpg
#   inflating: Cocoa Ripeness Dataset/S76.jpg
#   inflating: Cocoa Ripeness Dataset/S77.jpg
#   inflating: Cocoa Ripeness Dataset/S78.jpg
#   inflating: Cocoa Ripeness Dataset/S79.jpg
#   inflating: Cocoa Ripeness Dataset/S8.jpg
#   inflating: Cocoa Ripeness Dataset/S80.jpg
#   inflating: Cocoa Ripeness Dataset/S81.jpg
#   inflating: Cocoa Ripeness Dataset/S82.jpg
#   inflating: Cocoa Ripeness Dataset/S83.jpg
#   inflating: Cocoa Ripeness Dataset/S84.jpg
#   inflating: Cocoa Ripeness Dataset/S85.jpg
#   inflating: Cocoa Ripeness Dataset/S86.jpg
#   inflating: Cocoa Ripeness Dataset/S87.jpg
#   inflating: Cocoa Ripeness Dataset/S88.jpg
#   inflating: Cocoa Ripeness Dataset/S89.jpg
#   inflating: Cocoa Ripeness Dataset/S9.jpg
#   inflating: Cocoa Ripeness Dataset/S90.jpg
#   inflating: Cocoa Ripeness Dataset/S91.jpg
#   inflating: Cocoa Ripeness Dataset/S92.jpg
#   inflating: Cocoa Ripeness Dataset/S93.jpg
#   inflating: Cocoa Ripeness Dataset/S94.jpg
#   inflating: Cocoa Ripeness Dataset/S95.jpg
#   inflating: Cocoa Ripeness Dataset/S96.jpg
#   inflating: Cocoa Ripeness Dataset/S97.jpg
#   inflating: Cocoa Ripeness Dataset/S98.jpg
#   inflating: Cocoa Ripeness Dataset/S99.jpg

# %% [markdown]
# Import & pakai library yg diperlukan.

# %%
try:
  # This command only in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Membuat folder bernama Cocoa Ripeness Dataset

# %%
PATH = 'Cocoa Ripeness Dataset'
# membuat sub folder immature
immature_dir = os.path.join(PATH, 'immature')
os.makedirs(immature_dir)

# %%
import fnmatch
import shutil
# memindah list gambar yang berawalan I pada dataset ke dalam folder immature
for file in os.listdir(PATH):
    if fnmatch.fnmatch(file, 'I*'):
        shutil.move(PATH+'/'+file, immature_dir+'/'+file)

# %%
# membuat sub folder mature
mature_dir = os.path.join(PATH, 'mature')
os.makedirs(mature_dir)

# %%
# memindah list gambar yang berawalan M pada dataset ke dalam folder mature
for file in os.listdir(PATH):
    if fnmatch.fnmatch(file, 'M*'):
        shutil.move(PATH+'/'+file, mature_dir+'/'+file)

# %%
# membuat sub folder overmature
overmature_dir = os.path.join(PATH, 'overmature')
os.makedirs(overmature_dir)

# %%
# memindah list gambar yang berawalan M pada dataset ke dalam folder mature
for file in os.listdir(PATH):
    if fnmatch.fnmatch(file, 'S*'):
        shutil.move(PATH+'/'+file, overmature_dir+'/'+file)

# %%
y = ['immature','mature','overmature']

# %%
dir_name = [immature_dir,mature_dir,overmature_dir]

# %% [markdown]
# **PS : split to 80 train 20 validation later**
# >
# check files on runtime too(some error may occure)

# %%
for i in y:
  os.makedirs(PATH +'/train/' + i)
  os.makedirs(PATH +'/test/' + i)
  source = PATH + '/' + i
  for x in dir_name:
    allFileNames = os.listdir(x)
    np.random.shuffle(allFileNames)
    test_ratio = 0.1
    train_FileNames, test_FileNames = np.split(np.array(allFileNames),
                                                      [int(len(allFileNames)* (1 - test_ratio))])
    train_FileNames = [source+'/'+ name for name in train_FileNames.tolist()]
    test_FileNames = [source+'/' + name for name in test_FileNames.tolist()]
    for name in train_FileNames:
      shutil.move(name, PATH +'/train/' + i)
    for name in test_FileNames:
      shutil.move(name, PATH +'/test/' + i)

# %%
shutil.rmtree(mature_dir)
shutil.rmtree(immature_dir)
shutil.rmtree(overmature_dir)

# %%
train_dir = os.path.join(PATH, 'train')
test_dir = os.path.join(PATH, 'test')
IMG_HEIGHT = 150
IMG_WIDTH = 150
batch_size = 20

# %%
train_image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,)
test_image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,)

train_data_gen = train_image_generator.flow_from_directory(train_dir, 
                                                           target_size = (IMG_HEIGHT, IMG_WIDTH),
                                                           batch_size = batch_size,
                                                           class_mode = 'categorical')

test_data_gen = test_image_generator.flow_from_directory(test_dir,
                                                         target_size = (IMG_HEIGHT, IMG_WIDTH),
                                                         batch_size = batch_size,
                                                         shuffle = True)
# Out:
# Found 427 images belonging to 3 classes.
# Found 49 images belonging to 3 classes.

# %%
def plotImages(images_arr, probabilities = False):
    fig, axes = plt.subplots(len(images_arr), 1, figsize=(5,len(images_arr) * 3))
    if probabilities is False:
      for img, ax in zip( images_arr, axes):
          ax.imshow(img)
          ax.axis('off')
    # else:
    #   for img, probability, ax in zip( images_arr, probabilities, axes):
    #       ax.imshow(img)
    #       ax.axis('off')
    #       if probability > 0.5:
    #           ax.set_title("%.2f" % (probability*100) + "% dog")
    #       else:
    #           ax.set_title("%.2f" % ((1-probability)*100) + "% cat")
    plt.show()

sample_training_images, _ = next(train_data_gen)
plotImages(sample_training_images[:3])

# %%
train_image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                                        horizontal_flip=True,
                                                                        rotation_range=30,
                                                                        width_shift_range=0.2,
                                                                        height_shift_range=0.2,
                                                                        shear_range=0.2,
                                                                        zoom_range=0.4,
                                                                        fill_mode="nearest"
                                                                        )

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                     directory=train_dir,
                                                     target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                     class_mode='categorical')

augmented_images = [train_data_gen[10][0][0] for i in range(5)]

plotImages(augmented_images)
# Out:
# Found 427 images belonging to 3 classes.

# %%
model = Sequential([
    Conv2D(128, (3, 3), input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), activation='relu'),
    MaxPooling2D((2,2), padding = 'same'),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2,2), padding = 'same'),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2,2), padding = 'same'),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2,2), padding = 'same'),
    Flatten(),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='softmax'),
    ])

model.compile(
    optimizer='rmsprop', 
    loss='categorical_crossentropy', 
    metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 128)     3584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 64)        73792
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 32)        18464
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                131104
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 245,473
# Trainable params: 245,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping#set early stopping monitor so the model stops training when it won't improve anymore

early_stopping_monitor = EarlyStopping(patience=3)#train model

history = model.fit(
    train_data_gen,
    steps_per_epoch=15,
    epochs=5,
    validation_steps=7,
    callbacks=[early_stopping_monitor],
)
# Out:
# Epoch 1/5
# 15/15 [==============================] - 28s 2s/step - loss: 0.8943 - accuracy: 0.6511
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/5
# 15/15 [==============================] - 28s 2s/step - loss: 0.7158 - accuracy: 0.6644
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/5
# 15/15 [==============================] - 27s 2s/step - loss: 0.7233 - accuracy: 0.6887
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/5
# 15/15 [==============================] - 28s 2s/step - loss: 0.6617 - accuracy: 0.7444
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/5
# 15/15 [==============================] - 27s 2s/step - loss: 0.6310 - accuracy: 0.7863
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy

# %%
acc = history.history['accuracy']

loss = history.history['loss']

epochs_range = range(5)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.legend(loc='upper right')
plt.title('Training Loss')
plt.show()

# %%
augmented_images = [tte for i in range(5)]

plotImages(augmented_images)

# %%
probabilities = model.predict(test_data_gen)
print(probabilities)
# Out:
# [[0.36297315]
#  [0.37447006]
#  [0.36769116]
#  [0.3579207 ]
#  [0.3750812 ]
#  [0.36921003]
#  [0.36813223]
#  [0.36245948]
#  [0.371803  ]
#  [0.3602086 ]
#  [0.3586126 ]
#  [0.36306912]
#  [0.37186724]
#  [0.36585724]
#  [0.37565112]
#  [0.35597497]
#  [0.36999524]
#  [0.35797712]
#  [0.37225223]
#  [0.36051297]
#  [0.36201903]
#  [0.37237424]
#  [0.35888195]
#  [0.3661772 ]
#  [0.37275046]
#  [0.35993642]
#  [0.36874306]
#  [0.376629  ]
#  [0.38028967]
#  [0.37364683]
#  [0.36920717]
#  [0.36447197]
#  [0.37372464]
#  [0.36143517]
#  [0.37679788]
#  [0.37987164]
#  [0.37081593]
#  [0.3803206 ]
#  [0.3789737 ]
#  [0.37901822]
#  [0.38010514]
#  [0.37798786]
#  [0.37985203]
#  [0.37454757]
#  [0.37169164]
#  [0.3691607 ]
#  [0.36757046]
#  [0.37293884]
#  [0.37449795]]
